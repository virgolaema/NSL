# %% [markdown]
# # Esercitazione 4
#
# ## Esercizio 1
#
# Il semplice comando _make_ esegue le seguenti operazioni:
#
# - elimina i file delle posizioni e dei parametri di output creati al test precedente
# - salva in _config.0_ la _config.final_ del test precedente. In runtime viene chiesto all'utente se ripartire dallo step t-dt e se rinormalizzare tali posizioni per adattare alla temperatura voluta.
# - esegue il programma
#
# Inoltre, con _make solid_ e _make liquid_ vengono caricate in _input.dat_ le configurazioni solide o liquide fornite.

# %% [markdown]
# ### Punto 1
#
# Mostro che il mio sistema è stato termodinamicamente equilibrato.

# %%
import numpy as np
import matplotlib.pyplot as plt

Temp = np.loadtxt("es4/punto1/output_temp.dat", usecols=(0), unpack='true')

a = np.arange(1000)

plt.figure(figsize=(14,6))
plt.plot(a,Temp)
plt.xlabel('step')
plt.ylabel('Temp (LJ)')
plt.grid(True)
plt.show()

# %%
Etot = np.loadtxt("es4/punto1/output_etot.dat", usecols=(0), unpack='true')

a = np.arange(1000)

plt.figure(figsize=(14,6))
plt.plot(a,Etot)
plt.xlabel('step')
plt.ylabel('Etot (LJ)')
plt.grid(True)
plt.show()

# %%
Ekin = np.loadtxt("es4/punto1/output_ekin.dat", usecols=(0), unpack='true')

a = np.arange(1000)

plt.figure(figsize=(14,6))
plt.plot(a,Ekin)
plt.xlabel('step')
plt.ylabel('Ekin (LJ)')
plt.grid(True)
plt.show()

# %%
Epot = np.loadtxt("es4/punto1/output_epot.dat", usecols=(0), unpack='true')

a = np.arange(1000)

plt.figure(figsize=(14,6))
plt.plot(a,Epot)
plt.xlabel('step')
plt.ylabel('Epot (LJ)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Esercizio 4.2
#
# Ho aggiunto al codice delle stringhe per stimare le grandezze e le loro varianze utilizzando il metodo a blocchi. Utilizzo questa funzione nel punto 3 di seguito.

# %% [markdown]
# ## Esercizio 4.3
#
# Mostro l'andamento delle grandezze medie per particella in funzione del numero di blocchi, in unità SI. Eseguo le 3 simulazioni in sequenza, mostrando anche come il programma riequilibri correttamente le grandezze partendo da ogni condizione.
#
# ### Configurazione 1: solido

# %%
Nblocks, Epot, var_Epot = np.loadtxt("es4/3_1/ave_epot.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Epot,yerr=var_Epot**0.5, marker='', ecolor='red')
plt.xlabel('Nblocks')
plt.ylabel('Epot/N (J)')
plt.grid(True)
plt.show()

# %%
Nblocks, Ekin, var_Ekin = np.loadtxt("es4/3_1/ave_ekin.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Ekin,yerr=var_Ekin**0.5, marker='', ecolor='red')
plt.xlabel('Nblocks')
plt.ylabel('Ekin/N (J)')
plt.grid(True)
plt.show()

# %%
Nblocks, Etot, var_Etot = np.loadtxt("es4/3_1/ave_etot.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Etot,yerr=var_Etot**0.5, marker='', ecolor='red')
plt.xlabel('Nblocks')
plt.ylabel('Etot/N (J)')
plt.grid(True)
plt.show()

# %%
Nblocks, Temp, var_Temp = np.loadtxt("es4/3_1/ave_temp.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Temp,yerr=var_Temp**0.5, marker='', ecolor='red')
plt.xlabel('Nblocks')
plt.ylabel('Temp (K)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Configurazione 2: liquido.

# %%
Nblocks, Epot, var_Epot = np.loadtxt("es4/3_2/ave_epot.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Epot,yerr=var_Epot**0.5, marker='', ecolor='red')
plt.xlabel('Nblocks')
plt.ylabel('Epot/N (J)')
plt.grid(True)
plt.show()

# %%
Nblocks, Ekin, var_Ekin = np.loadtxt("es4/3_2/ave_ekin.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Ekin,yerr=var_Ekin**0.5, marker='', ecolor='red')
plt.xlabel('Nblocks')
plt.ylabel('Ekin/N (J)')
plt.grid(True)
plt.show()

# %%
Nblocks, Etot, var_Etot = np.loadtxt("es4/3_2/ave_etot.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Etot,yerr=var_Etot**0.5, marker='', ecolor='red')
plt.xlabel('Nblocks')
plt.ylabel('Etot/N (J)')
plt.grid(True)
plt.show()

# %%
Nblocks, Temp, var_Temp = np.loadtxt("es4/3_2/ave_temp.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Temp,yerr=var_Temp**0.5, marker='', ecolor='red')
plt.xlabel('Nblocks')
plt.ylabel('Temp (K)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Configurazione 3: gas

# %%
Nblocks, Epot, var_Epot = np.loadtxt("es4/3_3/ave_epot.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Epot,yerr=var_Epot**0.5, marker='', ecolor='red')
plt.xlabel('Nblocks')
plt.ylabel('Epot/N (J)')
plt.grid(True)
plt.show()

# %%
Nblocks, Ekin, var_Ekin = np.loadtxt("es4/3_3/ave_ekin.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Ekin,yerr=var_Ekin**0.5, marker='', ecolor='red')
plt.xlabel('Nblocks')
plt.ylabel('Ekin/N (J)')
plt.grid(True)
plt.show()

# %%
Nblocks, Etot, var_Etot = np.loadtxt("es4/3_3/ave_etot.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Etot,yerr=var_Etot**0.5, marker='', ecolor='red')
plt.xlabel('Nblocks')
plt.ylabel('Etot/N (J)')
plt.grid(True)
plt.show()

# %%
Nblocks, Temp, var_Temp = np.loadtxt("es4/3_3/ave_temp.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Temp,yerr=var_Temp**0.5, marker='', ecolor='red')
plt.xlabel('Nblocks')
plt.ylabel('Temp (K)')
plt.grid(True)
plt.show()
