# %% [markdown]
# # Esercitazione 6

# %%
import numpy as np
import matplotlib.pyplot as plt

N, E, stdev_E = np.loadtxt("es6/output.chi.0", usecols=(0,1,2), delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(N,E,yerr=stdev_E, marker='', ecolor='orange')
plt.xlabel('N')
plt.ylabel('E')
plt.grid(True)
plt.show()

# %%
N, E = np.loadtxt("es6/u_values.0", usecols=(0,1), delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(N,E,yerr=stdev_E, marker='', ecolor='orange')
plt.xlabel('N')
plt.ylabel('E')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-8a0462b262c4> in <module>
# ----> 1 N, E = np.loadtxt("es6u_values.0", usecols=(0,1), delimiter=',', unpack='true')
#       2
#       3 plt.figure(figsize=(14,6))
#       4 plt.errorbar(N,E,yerr=stdev_E, marker='', ecolor='orange')
#       5 plt.xlabel('N')
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     979             fname = os_fspath(fname)
#     980         if _is_string_like(fname):
# --> 981             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     982             fencoding = getattr(fh, 'encoding', 'latin1')
#     983             fh = iter(fh)
#
# ...

# %%
/
