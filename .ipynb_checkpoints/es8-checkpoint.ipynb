# %% [markdown]
# # Esercitazione 8
#
# ## Esercizio 1

# %%
import numpy as np
import matplotlib.pyplot as plt

N, val, stdev = np.loadtxt("es8_1/name.out", usecols=(0,1,2), delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(N, val, yerr = stdev)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

N, val = np.loadtxt("es8_1/wave.out", usecols=(0,1,2), delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.plot(N, val)
plt.show()
