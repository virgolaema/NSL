# %% [markdown]
# # Esercitazione 4
#
# ## Esercizio 1
#
# Ho modificato il makefile, così che con il semplice comando _make_ vengano eseguite le seguenti operazioni:
#
# - vengono eliminati i file delle posizioni e dei parametri di output creati al test precedente
# - salva in _config.0_ la _config.final_ del test precedente. In runtime viene chiesto all'utente se ripartire dallo step t-dt e se rinormalizzare tali posizioni per adattare alla temperatura voluta.
# - esecuzione del programma
#
# Inoltre, con _make solid_ e _make liquid_ vengono caricate in _input.dat_ le configurazioni solide o liquide fornite.

# %% [markdown]
# ### Punto 1

# %%
import numpy as np
import matplotlib.pyplot as plt

Temp = np.loadtxt("es4/punto1/output_temp.dat", usecols=(0), unpack='true')

a = np.arange(1000)

plt.figure(figsize=(14,6))
plt.plot(a,Temp)
plt.xlabel('step')
plt.ylabel('Temp (LJ)')
plt.grid(True)
plt.show()

# %%
Etot = np.loadtxt("es4/punto1/output_etot.dat", usecols=(0), unpack='true')

a = np.arange(1000)

plt.figure(figsize=(14,6))
plt.plot(a,Etot)
plt.xlabel('step')
plt.ylabel('Etot (LJ)')
plt.grid(True)
plt.show()

# %%
Ekin = np.loadtxt("es4/punto1/output_ekin.dat", usecols=(0), unpack='true')

a = np.arange(1000)

plt.figure(figsize=(14,6))
plt.plot(a,Ekin)
plt.xlabel('step')
plt.ylabel('Ekin (LJ)')
plt.grid(True)
plt.show()

# %%
Epot = np.loadtxt("es4/punto1/output_epot.dat", usecols=(0), unpack='true')

a = np.arange(1000)

plt.figure(figsize=(14,6))
plt.plot(a,Epot)
plt.xlabel('step')
plt.ylabel('Epot (LJ)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Punto 2

# %%
Nblocks, Epot, stdev_Epot = np.loadtxt("es4/ave_etot.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Epot,yerr=stdev_Epot, marker='', ecolor='red')
plt.xlabel('N')
plt.ylabel('Epot (LJ)')
plt.grid(True)
plt.show()

# %%
Nblocks, Ekin, stdev_Ekin = np.loadtxt("es4/ave_ekin.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Ekin,yerr=stdev_Ekin, marker='', ecolor='red')
plt.xlabel('N')
plt.ylabel('Epot (LJ)')
plt.grid(True)
plt.show()

# %%
Nblocks, Etot, stdev_Etot = np.loadtxt("es4/ave_etot.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Etot,yerr=stdev_Etot, marker='', ecolor='red')
plt.xlabel('N')
plt.ylabel('Epot (LJ)')
plt.grid(True)
plt.show()

# %%
Nblocks, Temp, stdev_Temp = np.loadtxt("es4/ave_temp.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Temp,yerr=stdev_Temp, marker='', ecolor='red')
plt.xlabel('N')
plt.ylabel('Temp (K)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Punto 3
# Configurazione 1: solido.

# %%
Nblocks, Epot, stdev_Epot = np.loadtxt("es4/1/ave_etot.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Epot,yerr=stdev_Epot, marker='', ecolor='red')
plt.xlabel('N')
plt.ylabel('Epot (LJ)')
plt.grid(True)
plt.show()

# %%
Nblocks, Ekin, stdev_Ekin = np.loadtxt("es4/1/ave_ekin.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Ekin,yerr=stdev_Ekin, marker='', ecolor='red')
plt.xlabel('N')
plt.ylabel('Epot (LJ)')
plt.grid(True)
plt.show()

# %%
Nblocks, Etot, stdev_Etot = np.loadtxt("es4/1/ave_etot.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Etot,yerr=stdev_Etot, marker='', ecolor='red')
plt.xlabel('N')
plt.ylabel('Epot (LJ)')
plt.grid(True)
plt.show()

# %%
Nblocks, Temp, stdev_Temp = np.loadtxt("es4/1/ave_temp.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Temp,yerr=stdev_Temp, marker='', ecolor='red')
plt.xlabel('N')
plt.ylabel('Temp (K)')
plt.grid(True)
plt.show()

# %% [markdown]
# Configurazione 2: liquido.

# %%
Nblocks, Epot, stdev_Epot = np.loadtxt("es4/2/ave_etot.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Epot,yerr=stdev_Epot, marker='', ecolor='red')
plt.xlabel('N')
plt.ylabel('Epot (LJ)')
plt.grid(True)
plt.show()

# %%
Nblocks, Ekin, stdev_Ekin = np.loadtxt("es4/2/ave_ekin.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Ekin,yerr=stdev_Ekin, marker='', ecolor='red')
plt.xlabel('N')
plt.ylabel('Epot (LJ)')
plt.grid(True)
plt.show()

# %%
Nblocks, Etot, stdev_Etot = np.loadtxt("es4/2/ave_etot.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Etot,yerr=stdev_Etot, marker='', ecolor='red')
plt.xlabel('N')
plt.ylabel('Epot (LJ)')
plt.grid(True)
plt.show()

# %%
Nblocks, Temp, stdev_Temp = np.loadtxt("es4/2/ave_temp.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Temp,yerr=stdev_Temp, marker='', ecolor='red')
plt.xlabel('N')
plt.ylabel('Temp (K)')
plt.grid(True)
plt.show()

# %% [markdown]
# Configurazione 3: gas.

# %%
Nblocks, Epot, stdev_Epot = np.loadtxt("es4/3/ave_etot.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Epot,yerr=stdev_Epot, marker='', ecolor='red')
plt.xlabel('N')
plt.ylabel('Epot (LJ)')
plt.grid(True)
plt.show()

# %%
Nblocks, Ekin, stdev_Ekin = np.loadtxt("es4/3/ave_ekin.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Ekin,yerr=stdev_Ekin, marker='', ecolor='red')
plt.xlabel('N')
plt.ylabel('Epot (LJ)')
plt.grid(True)
plt.show()

# %%
Nblocks, Etot, stdev_Etot = np.loadtxt("es4/3/ave_etot.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Etot,yerr=stdev_Etot, marker='', ecolor='red')
plt.xlabel('N')
plt.ylabel('Epot (LJ)')
plt.grid(True)
plt.show()

# %%
Nblocks, Temp, stdev_Temp = np.loadtxt("es4/3/ave_temp.out", usecols=(0,1,2) , delimiter=',', unpack='true')

plt.figure(figsize=(14,6))
plt.errorbar(Nblocks,Temp,yerr=stdev_Temp, marker='', ecolor='red')
plt.xlabel('N')
plt.ylabel('Temp (K)')
plt.grid(True)
plt.show()
